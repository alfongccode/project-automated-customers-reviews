# %% [markdown]
# ### Extract random SEED data for Django localhost database

# %%
import os
import sys
import pandas as pd

project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.append(project_root)

# %%
OUTPUT_SEED_DATA_DIR = '../storage/seed_data'
OUTPUT_FILE_NAME = 'products.csv'

# %%
from lib.data_load import load_data

df = await load_data()
print(f"\n{'CONCATENATED':<62} {df.shape[0]:>6,} rows x {df.shape[1]} cols")
df.sample(10)
# Out:
# 1429_1.csv                                                     34,660 rows
# Datafiniti_Amazon_Consumer_Reviews_of_Amazon_Products.csv       5,000 rows
# Datafiniti_Amazon_Consumer_Reviews_of_Amazon_Products_May19.csv 28,332 rows
#
# CONCATENATED                                                   67,992 rows x 28 cols
#                          id  \
# 60065  AVwjfXp4QMlgsOJE8qmk
# 21620  AV1YnR7wglJLPUi8IJmi
# 40731  AVpgNzjwLJeJML43Kpxn
# 27528  AVpfl8cLLJeJML43AE3S
# 66372  AVqkIhxunnc1JgDc3kg_
# 66756  AVqkIhxunnc1JgDc3kg_
# 41991  AVpgNzjwLJeJML43Kpxn
# 46115  AVpgNzjwLJeJML43Kpxn
# 45461  AVpgNzjwLJeJML43Kpxn
# 66848  AVqkIhxunnc1JgDc3kg_
#
#                                                     name  \
# 60065  All-New Fire HD 8 Kids Edition Tablet, 8 HD Di...
# 21620                 Echo (White),,,\r\nEcho (White),,,
# 40731  AmazonBasics AAA Performance Alkaline Batterie...
# 27528             Amazon Fire Tv,,,\r\nAmazon Fire Tv,,,
# ...

# %%
df_output = pd.DataFrame()
random_products = df.sample(20)
for i, row in random_products.iterrows():
    row_index = df.index.get_loc(i)
    df_output = pd.concat([df_output, df.iloc[row_index:row_index + 5]]).reset_index(drop=True)
    
print(df_output['asins'].value_counts())

df_output.to_csv(os.path.join(OUTPUT_SEED_DATA_DIR, OUTPUT_FILE_NAME), index=False)
# Out:
# asins
# B018Y229OU                          30
# B00L9EPT8O,B01E6AO69U               15
# B00QWO9P0O,B01IB83NZG,B00MNV8E0C    15
# B00QWO9P0O,B00LH3DMUO               10
# B018SZT3BK,B01AHB9CN2                9
# B018Y226XO                           6
# B00U3FPN4U                           5
# B018Y225IA                           5
# B018Y22C2Y                           4
# B018Y22BI4                           1
# Name: count, dtype: int64
